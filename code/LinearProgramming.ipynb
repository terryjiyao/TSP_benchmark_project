# %%
import pandas as pd
import numpy as np
import time

data = pd.read_csv('tiny.csv', header = None, names = ['x', 'y'])
cities = data[['x', 'y']].values  # assuming your CSV has 'x' and 'y' columns
n = len(cities)
data
# Out:
#           x         y
# 0 -1.085631 -0.678886
# 1  0.997345 -0.094709
# 2  0.282978  1.491390
# 3 -1.506295 -0.638902
# 4 -0.578600 -0.443982
# 5  1.651437 -0.434351
# 6 -2.426679  2.205930
# 7 -0.428913  2.186786
# 8  1.265936  1.004054
# 9 -0.866740  0.386186

# %%
# distance matrix
dist_matrix = np.zeros((n, n))
for i in range(n):
    for j in range(n):
        dist_matrix[i, j] = np.linalg.norm(cities[i] - cities[j])

# %%
# brute force
from itertools import permutations


def compute_distance(tour_path):
    # given an order of cities to visit, and compute teh distance need to travel.
    dist = 0
    for i in range(len(tour_path) - 1):
        dist += dist_matrix[tour_path[i], tour_path[i+1]]
    # visit all the cities, but but not return to city1
    dist += dist_matrix[tour_path[i], tour_path[0]] # return to the starting point
    return dist

best_tour = None
min_distance = float('inf')


start_time = time.time()

for perm in permutations(range(1, n)):
    tour = (0,) + perm  # Prepend city 0 as the fixed starting point
    current_distance = compute_distance(tour)
    if current_distance < min_distance:
        min_distance = current_distance
        best_tour = tour
        
elapsed_time = time.time() - start_time

print("Using brute force: ")
print("time used: {:.4f} seconds".format(elapsed_time))
print("Best tour:", best_tour)
print("Minimum distance:", min_distance)
# Out:
# Using brute force:
# time used: 0.9588 seconds
# Best tour: (0, 3, 4, 1, 5, 8, 2, 7, 9, 6)
# Minimum distance: 12.640430188095191

# %% [markdown]
# the above code performs the brute force on 10cities, and find the best route starting from city[0]

# %% [markdown]
# # Integer Linear Programming
#
# We introduce a martix X, for each pair of cities i and j. X_ij = 1 if the route from city i to j is included, and 0 otherwise
# The goal is to minimize the total travel distance represented by "min \sum_i \sum_j d_{ij} X_{ij}"
#
# Some constraints we have:
# 1. Each city is left exactly once: \sum_j X_{ij} = 1
# 2. Each city is entered exactly once: \sum_i X_{ij} = 1

# %%
import pulp

# %%
# Define the ILP problem
problem = pulp.LpProblem("TSP", pulp.LpMinimize)

# Decision variables: x[i][j] is 1 if the route from city i to j is used
x = pulp.LpVariable.dicts('x', (range(n), range(n)), cat='Binary')

# MTZ variables: u[i] helps to eliminate subtours (only needed for cities 1 to n-1)
u = pulp.LpVariable.dicts('u', range(n), lowBound=0, upBound=n, cat='Continuous')

# Objective function: minimize total travel distance
problem += pulp.lpSum(dist_matrix[i][j] * x[i][j] for i in range(n) for j in range(n)), "TotalDistance"

# Degree constraints: each city leaves and enters exactly once
for i in range(n):
    problem += pulp.lpSum(x[i][j] for j in range(n) if j != i) == 1, f"Out_{i}"
    problem += pulp.lpSum(x[j][i] for j in range(n) if j != i) == 1, f"In_{i}"

# MTZ Subtour elimination constraints (for cities 1 to n-1)
for i in range(1, n):
    for j in range(1, n):
        if i != j:
            problem += u[i] - u[j] + n * x[i][j] <= n - 1, f"MTZ_{i}_{j}"

# Solve the problem using PuLP's default solver (CBC)
problem.solve()

# Output the results
# print("Status:", pulp.LpStatus[problem.status])
# print("Total distance:", pulp.value(problem.objective))
solution_edges = [(i, j) for i in range(n) for j in range(n) if pulp.value(x[i][j]) == 1]
print("Edges in the solution tour:", solution_edges)
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/johnnyhuang/anaconda3/lib/python3.11/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/w8/6cb3vj053ps4rvg711krptd00000gn/T/b2d3243bd31a4990b69088e26892e503-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/w8/6cb3vj053ps4rvg711krptd00000gn/T/b2d3243bd31a4990b69088e26892e503-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 97 COLUMNS
# At line 764 RHS
# At line 857 BOUNDS
# At line 957 ENDATA
# Problem MODEL has 92 rows, 99 columns and 396 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 10.5865 - 0.00 seconds
# Cgl0004I processed model has 92 rows, 99 columns (90 integer (90 of which binary)) and 396 elements
# Cbc0038I Initial state - 19 integers unsatisfied sum - 2
# Cbc0038I Pass   1: suminf.    1.60000 (8) obj. 11.1255 iterations 24
# Cbc0038I Pass   2: suminf.    1.60000 (8) obj. 14.6446 iterations 17
# Cbc0038I Pass   3: suminf.    1.60000 (8) obj. 14.895 iterations 10
# Cbc0038I Pass   4: suminf.    2.40000 (8) obj. 16.5811 iterations 25
# Cbc0038I Pass   5: suminf.    1.00000 (9) obj. 15.4946 iterations 19
# Cbc0038I Pass   6: suminf.    1.20000 (4) obj. 15.8569 iterations 21
# Cbc0038I Pass   7: suminf.    1.00000 (9) obj. 15.7174 iterations 16
# Cbc0038I Pass   8: suminf.    1.20000 (4) obj. 15.5227 iterations 22
# Cbc0038I Pass   9: suminf.    1.20000 (4) obj. 19.9679 iterations 41
# Cbc0038I Pass  10: suminf.    0.60000 (6) obj. 20.3086 iterations 16
# Cbc0038I Pass  11: suminf.    0.60000 (6) obj. 20.3086 iterations 10
# Cbc0038I Pass  12: suminf.    1.80000 (15) obj. 17.5645 iterations 32
# Cbc0038I Pass  13: suminf.    1.40000 (8) obj. 18.1635 iterations 18
# Cbc0038I Pass  14: suminf.    1.40000 (9) obj. 20.4485 iterations 15
# Cbc0038I Pass  15: suminf.    1.40000 (4) obj. 19.1739 iterations 18
# Cbc0038I Pass  16: suminf.    1.40000 (4) obj. 19.1739 iterations 6
# Cbc0038I Pass  17: suminf.    1.40000 (9) obj. 21.402 iterations 20
# Cbc0038I Pass  18: suminf.    1.40000 (4) obj. 21.1347 iterations 18
# Cbc0038I Pass  19: suminf.    1.40000 (4) obj. 21.1347 iterations 10
# Cbc0038I Pass  20: suminf.    1.40000 (9) obj. 20.4485 iterations 12
# Cbc0038I Pass  21: suminf.    1.40000 (4) obj. 19.1739 iterations 17
# Cbc0038I Pass  22: suminf.    1.40000 (4) obj. 19.1739 iterations 6
# Cbc0038I Pass  23: suminf.    1.40000 (9) obj. 21.402 iterations 23
# Cbc0038I Pass  24: suminf.    1.40000 (4) obj. 21.1347 iterations 22
# Cbc0038I Pass  25: suminf.    1.40000 (4) obj. 21.1347 iterations 10
# Cbc0038I Pass  26: suminf.    1.40000 (9) obj. 20.4485 iterations 13
# Cbc0038I Pass  27: suminf.    1.40000 (4) obj. 19.1739 iterations 19
# Cbc0038I Pass  28: suminf.    1.40000 (4) obj. 19.1739 iterations 5
# Cbc0038I Pass  29: suminf.    1.40000 (9) obj. 21.402 iterations 21
# Cbc0038I Pass  30: suminf.    1.40000 (4) obj. 21.1347 iterations 20
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 39 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 92 rows 99 columns, reduced to 90 rows 58 columns
# Cbc0038I Mini branch and bound improved solution from 1.79769e+308 to 12.517 (0.10 seconds)
# Cbc0038I Round again with cutoff of 12.3239
# Cbc0038I Reduced cost fixing fixed 16 variables on major pass 2
# Cbc0038I Pass  30: suminf.    1.60000 (8) obj. 11.1255 iterations 0
# Cbc0038I Pass  31: suminf.    1.97812 (9) obj. 12.3239 iterations 14
# Cbc0038I Pass  32: suminf.    1.60000 (10) obj. 12.3239 iterations 9
# Cbc0038I Pass  33: suminf.    1.86581 (9) obj. 12.3239 iterations 25
# Cbc0038I Pass  34: suminf.    1.60000 (10) obj. 12.3239 iterations 13
# Cbc0038I Pass  35: suminf.    2.20000 (10) obj. 12.3239 iterations 30
# Cbc0038I Pass  36: suminf.    1.97795 (10) obj. 12.3239 iterations 13
# Cbc0038I Pass  37: suminf.    1.60000 (10) obj. 12.3239 iterations 11
# Cbc0038I Pass  38: suminf.    1.86581 (9) obj. 12.3239 iterations 25
# Cbc0038I Pass  39: suminf.    1.60000 (10) obj. 12.3239 iterations 18
# Cbc0038I Pass  40: suminf.    2.20000 (10) obj. 12.3239 iterations 24
# Cbc0038I Pass  41: suminf.    1.97795 (10) obj. 12.3239 iterations 13
# Cbc0038I Pass  42: suminf.    1.60000 (10) obj. 12.3239 iterations 10
# Cbc0038I Pass  43: suminf.    1.86581 (9) obj. 12.3239 iterations 19
# Cbc0038I Pass  44: suminf.    1.60000 (10) obj. 12.3239 iterations 10
# Cbc0038I Pass  45: suminf.    2.20000 (10) obj. 12.3239 iterations 22
# Cbc0038I Pass  46: suminf.    1.97795 (10) obj. 12.3239 iterations 18
# Cbc0038I Pass  47: suminf.    1.60000 (10) obj. 12.3239 iterations 8
# Cbc0038I Pass  48: suminf.    1.86581 (9) obj. 12.3239 iterations 28
# Cbc0038I Pass  49: suminf.    1.60000 (10) obj. 12.3239 iterations 13
# Cbc0038I Pass  50: suminf.    2.20000 (10) obj. 12.3239 iterations 30
# Cbc0038I Pass  51: suminf.    1.97795 (10) obj. 12.3239 iterations 14
# Cbc0038I Pass  52: suminf.    1.60000 (10) obj. 12.3239 iterations 12
# Cbc0038I Pass  53: suminf.    1.86581 (9) obj. 12.3239 iterations 16
# Cbc0038I Pass  54: suminf.    1.60000 (10) obj. 12.3239 iterations 13
# Cbc0038I Pass  55: suminf.    2.20000 (10) obj. 12.3239 iterations 38
# Cbc0038I Pass  56: suminf.    1.97795 (10) obj. 12.3239 iterations 17
# Cbc0038I Pass  57: suminf.    1.60000 (10) obj. 12.3239 iterations 3
# Cbc0038I Pass  58: suminf.    1.86581 (9) obj. 12.3239 iterations 28
# Cbc0038I Pass  59: suminf.    1.60000 (10) obj. 12.3239 iterations 11
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 64 integers at bound fixed and 1 continuous
# Cbc0038I Full problem 92 rows 99 columns, reduced to 33 rows 25 columns
# Cbc0038I Mini branch and bound did not improve solution (0.12 seconds)
# Cbc0038I After 0.12 seconds - Feasibility pump exiting with objective of 12.517 - took 0.06 seconds
# Cbc0012I Integer solution of 12.516978 found by feasibility pump after 0 iterations and 0 nodes (0.12 seconds)
# Cbc0038I Full problem 92 rows 99 columns, reduced to 78 rows 18 columns
# Cbc0031I 10 added rows had average density of 9.4
# Cbc0013I At root node, 10 cuts changed objective from 10.586496 to 12.051251 in 7 passes
# Cbc0014I Cut generator 0 (Probing) - 40 row cuts average 2.7 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 7 row cuts average 16.1 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 17 row cuts average 2.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 124 row cuts average 18.1 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is 1
# Cbc0010I After 0 nodes, 1 on tree, 12.516978 best solution, best possible 12.051251 (0.13 seconds)
# Cbc0001I Search completed - best objective 12.5169780397901, took 320 iterations and 6 nodes (0.15 seconds)
# Cbc0032I Strong branching done 94 times (952 iterations), fathomed 3 nodes and fixed 4 variables
# Cbc0035I Maximum depth 2, 68 variables fixed on reduced cost
# Cuts at root node changed objective from 10.5865 to 12.0513
# Probing was tried 24 times and created 134 cuts of which 0 were active after adding rounds of cuts (0.003 seconds)
# Gomory was tried 7 times and created 7 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 7 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# Clique was tried 7 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 24 times and created 46 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# FlowCover was tried 7 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# TwoMirCuts was tried 24 times and created 276 cuts of which 0 were active after adding rounds of cuts (0.004 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                12.51697804
# Enumerated nodes:               6
# Total iterations:               320
# Time (CPU seconds):             0.09
# Time (Wallclock seconds):       0.15
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.10   (Wallclock seconds):       0.16
#
# Edges in the solution tour: [(0, 3), (1, 4), (2, 8), (3, 9), (4, 0), (5, 1), (6, 7), (7, 2), (8, 5), (9, 6)]
